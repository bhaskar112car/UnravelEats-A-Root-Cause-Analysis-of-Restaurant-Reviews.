# %% [markdown]
# # NLP Project

# %%
# pip install langdetect -- upgrade

# %%
# pip install googletrans --upgrade

# %%
# pip install translate

# %%
# !pip install translate

# %%
# pip install py-translate

# %%
# !pip install httpx

# %%
# !pip install textblob

# %%
# !pip install langid

# %%
# ! pip install deep_translator

# %%
# ! pip install pytesseract --upgrade

# %%
# pip install --upgrade pip

# %%
# !pip install polyglot

# %%
# !pip install nltk --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.7)
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.5)
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1
#   WARNING: The script nltk.exe is installed in 'C:\Users\Personal00\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
PYTHONIOENCODING=utf8 
# pip install polyglot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7476\785871179.py in <module>
# ----> 1 PYTHONIOENCODING=utf8
#       2 # pip install polyglot
#
# NameError: name 'utf8' is not defined

# %%
PYTHONIOENCODING=utf8 pip install polyglot
# Out:
#   File "C:\Users\Personal00\AppData\Local\Temp\ipykernel_7476\551740111.py", line 1
#     PYTHONIOENCODING=utf8 pip install polyglot
#                           ^
# SyntaxError: invalid syntax

# %%
import pytesseract

# Set the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import nltk as nltk
import pandas as pd
from langdetect import detect
from googletrans import Translator
from translate import translator,translate
from deep_translator import GoogleTranslator
from PIL import Image
import pytesseract
import os

# %%
# Open the image
img = Image.open(r'image.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=645x756>

# %%
text = pytesseract.image_to_string(img)

# %%
# Print the extracted text
print(text)
# Out:
# Second Innings- Data science
# Akhil, Ashish, Chetana, Dhanshii, Jyoti, Mohan, Sagar, Shilpa, Supriya, Vishwesh , +91
#
# Soni aa en
#
# CJ
#
# ‘As a data analyst, you may encounter time series data frequently. Time series data
# refers to observations made over a period of time, and is often used in fields such
# as finance, economics, and weather forecasting. In this post, we will explore the
# basics of time series analysis, including the definition of time series, the four
# components of a time series, and examples of time series analysis applications.
#
# Atime series is a set of observations of a single variable over a period of time.
# Time series data is different from cross-sectional data, which refers to
# observations made at a single point in time across multiple variables.
#
# Time series analysis involves identifying patterns and trends in the data, as well as
# forecasting future values. One of the first steps in time series analysis is
# decomposing the time series into its four components:
#
# @ Trend: The trend component refers to the overall direction of the time series
# cover time. This can be increasing, decreasing, or flat.
#
# Seasonality: The seasonality component refers to the regular, repeating
# pattems in the data that occur within a year or other fixed time interval.
#
# © Cyclicity: The cyclicity component refers to the periodic, but less frequent,
# pattems in the data that are not fixed to a specific time interval.
#
# © irregularity: The irregularity component refers to the random fluctuations in the
# data that are not accounted for by the other three components.
#
# ‘Once the time series has been decomposed into its components, various
# statistical models can be applied to the data to identify patterns and trends, and ()
# to make pre dictions about future values. Some common time series analysis
#
# © @  Typeamessage

# %%
# pip install googletrans==4.0.0rc1

# %%
# import dataset 
df=pd.read_csv(r'Restaurant_Reviews.tsv',sep='\t')

# %%
revdf=df[['Review']]
revdf
# Out:
#                                                 Review
# 0                             Wow... Loved this place.
# 1                                   Crust is not good.
# 2            Not tasty and the texture was just nasty.
# 3    Stopped by during the late May bank holiday of...
# 4    The selection on the menu was great and so wer...
# ..                                                 ...
# 995  I think food should have flavor and texture an...
# 996                           Appetite instantly gone.
# 997  Overall I was not impressed and would not go b...
# 998  The whole experience was underwhelming, and I ...
# 999  Then, as if I hadn't wasted enough of my life ...
#
# [1000 rows x 1 columns]

# %%
from langdetect import detect

def detect_language(text):
    language = detect(text)
    return language

# %%
revdf['language'] = revdf['Review'].apply(detect_language)

# %%
revdf.language.value_counts()
# Out:
# en    963
# af      8
# fr      4
# nl      3
# da      3
# it      3
# de      2
# so      2
# no      2
# ca      2
# ro      2
# et      2
# tl      1
# vi      1
# es      1
# sq      1
# Name: language, dtype: int64

# %%
A=revdf.loc[revdf['language']!='en']
A
# Out:
#                                                 Review language
# 19                                did not like at all.       af
# 88                             Omelets are to die for!       af
# 93                            Best breakfast buffet!!!       de
# 109                                      Sooooo good!!       so
# 117                        I've had better atmosphere.       no
# 131                             Penne vodka excellent!       fr
# 133                            The management is rude.       nl
# 140                                    Don't do it!!!!       nl
# 163                                 Avoid at all cost!       ca
# 165                                        DELICIOUS!!       de
# 246               Seriously flavorful delights, folks.       da
# 369                               He deserves 5 stars.       da
# 425                                     No complaints!       fr
# 427                                 Waiter was a jerk.       af
# 430                                I never come again.       it
# 437  I like Steiners because it's dark and it feels...       af
# 440    I'll take my business dinner dollars elsewhere.       no
# 451                                Food was so gooodd.       so
# 534                               Terrible management.       fr
# 538                                Worst martini ever!       da
# 551                                     Nice ambiance.       ro
# 614                            An absolute must visit!       et
# 621                              Very disappointing!!!       tl
# 646                                    What a mistake.       et
# 670                                      dont go here.       nl
# 684                                   Damn good steak.       af
# 711                                      Not my thing.       vi
# 714  I loved the grilled pizza, reminded me of legi...       it
# 720                      Cute, quaint, simple, honest.       fr
# 765                                  Tasted like dirt.       af
# 778                 My girlfriend's veal was very bad.       af
# 800                                   I'm super pissd.       ca
# 824                                     Awful service.       ro
# 877                             Go To Place for Gyros.       es
# 911                                    Very, very sad.       af
# 966                               But I don't like it.       sq
# 967                             Hell no will I go back       it

# %%
# language detection and translation function
def lang_trans(data: 'data_column'):
    # detect the language of the data
    lang = detect(data)
    # if the language is English, return the data as it is
    if lang == 'en':
        return data
    # otherwise, use GoogleTranslator to translate the data to English
    else:
        # create a GoogleTranslator object with auto source and English target
        google_translator = GoogleTranslator(source='auto', target='en')
        # translate the data and return it
        translated_data = google_translator.translate(data)
        return translated_data

# %%
revdf['trans_review']=revdf.Review.apply(lang_trans)
revdf[['trans_review']]
# Out:
#                                           trans_review
# 0                             Wow... Loved this place.
# 1                                   Crust is not good.
# 2            Not tasty and the texture was just nasty.
# 3    Stopped by during the late May bank holiday of...
# 4    The selection on the menu was great and so wer...
# ..                                                 ...
# 995  I think food should have flavor and texture an...
# 996                           Appetite instantly gone.
# 997  Overall I was not impressed and would not go b...
# 998  The whole experience was underwhelming, and I ...
# 999  Then, as if I hadn't wasted enough of my life ...
#
# [1000 rows x 1 columns]

# %%
revdf['language']=revdf.trans_review.apply(detect_language)
revdf
# Out:
#                                                 Review language  \
# 0                             Wow... Loved this place.       en
# 1                                   Crust is not good.       en
# 2            Not tasty and the texture was just nasty.       en
# 3    Stopped by during the late May bank holiday of...       en
# 4    The selection on the menu was great and so wer...       en
# ..                                                 ...      ...
# 995  I think food should have flavor and texture an...       en
# 996                           Appetite instantly gone.       en
# 997  Overall I was not impressed and would not go b...       en
# 998  The whole experience was underwhelming, and I ...       en
# 999  Then, as if I hadn't wasted enough of my life ...       en
#
#                                           trans_review
# 0                             Wow... Loved this place.
# 1                                   Crust is not good.
# 2            Not tasty and the texture was just nasty.
# 3    Stopped by during the late May bank holiday of...
# 4    The selection on the menu was great and so wer...
# ..                                                 ...
# 995  I think food should have flavor and texture an...
# 996                           Appetite instantly gone.
# 997  Overall I was not impressed and would not go b...
# 998  The whole experience was underwhelming, and I ...
# 999  Then, as if I hadn't wasted enough of my life ...
#
# [1000 rows x 3 columns]

# %%
revdf.language.value_counts()
# Out:
# en    962
# af      9
# no      4
# fr      4
# nl      3
# da      3
# so      2
# ca      2
# it      2
# ro      2
# et      2
# de      1
# hr      1
# tl      1
# es      1
# sq      1
# Name: language, dtype: int64

# %%
A=revdf.loc[revdf['language']!='en']
A
# Out:
#                                                 Review language  \
# 19                                did not like at all.       af
# 88                             Omelets are to die for!       af
# 93                            Best breakfast buffet!!!       no
# 109                                      Sooooo good!!       so
# 117                        I've had better atmosphere.       no
# 131                             Penne vodka excellent!       fr
# 133                            The management is rude.       nl
# 140                                    Don't do it!!!!       nl
# 163                                 Avoid at all cost!       ca
# 165                                        DELICIOUS!!       de
# 198                               Very friendly staff.       da
# 369                               He deserves 5 stars.       da
# 425                                     No complaints!       fr
# 427                                 Waiter was a jerk.       af
# 430                                I never come again.       it
# 437  I like Steiners because it's dark and it feels...       af
# 440    I'll take my business dinner dollars elsewhere.       no
# 451                                Food was so gooodd.       so
# 534                               Terrible management.       fr
# 538                                Worst martini ever!       da
# 551                                     Nice ambiance.       ro
# 562                                       A good time!       hr
# 604           Couldn't ask for a more satisfying meal.       no
# 614                            An absolute must visit!       et
# 621                              Very disappointing!!!       tl
# 646                                    What a mistake.       et
# 670                                      dont go here.       nl
# 684                                   Damn good steak.       af
# 718                      After one bite, I was hooked.       af
# 720                      Cute, quaint, simple, honest.       fr
# 765                                  Tasted like dirt.       af
# 778                 My girlfriend's veal was very bad.       af
# 800                                   I'm super pissd.       ca
# 824                                     Awful service.       ro
# 877                             Go To Place for Gyros.       es
# 911                                    Very, very sad.       af
# 966                               But I don't like it.       sq
# 967                             Hell no will I go back       it
#
#                                           trans_review
# 19                                did not like at all.
# 88                             Omelets are to die for!
# 93                            Best breakfast buffet!!!
# 109                                      Sooooo good!!
# 117                        I've had better atmosphere.
# 131                             Penne vodka excellent!
# 133                            The management is rude.
# 140                                    Don't do it!!!!
# 163                                 Avoid at all cost!
# 165                                        DELICIOUS!!
# 198                               Very friendly staff.
# 369                               He deserves 5 stars.
# 425                                     No complaints!
# 427                                 Waiter was a jerk.
# 430                                I never come again.
# 437  I like Steiners because it's dark and it feels...
# 440    I'll take my business dinner dollars elsewhere.
# 451                                Food was so gooodd.
# 534                               Terrible management.
# 538                                Worst martini ever!
# 551                                     Nice ambiance.
# 562                                       A good time!
# 604           Couldn't ask for a more satisfying meal.
# 614                            An absolute must visit!
# 621                              Very disappointing!!!
# 646                                    What a mistake.
# 670                                      dont go here.
# 684                                   Damn good steak.
# 718                      After one bite, I was hooked.
# 720                      Cute, quaint, simple, honest.
# 765                                  Tasted like dirt.
# 778                 My girlfriend's veal was very bad.
# 800                                   I'm super pissd.
# 824                                     Awful service.
# 877                             Go To Place for Gyros.
# 911                                    Very, very sad.
# 966                               But I don't like it.
# 967                             Hell no will I go back

# %%
df=revdf[['trans_review']]
df
# Out:
#                                           trans_review
# 0                             Wow... Loved this place.
# 1                                   Crust is not good.
# 2            Not tasty and the texture was just nasty.
# 3    Stopped by during the late May bank holiday of...
# 4    The selection on the menu was great and so wer...
# ..                                                 ...
# 995  I think food should have flavor and texture an...
# 996                           Appetite instantly gone.
# 997  Overall I was not impressed and would not go b...
# 998  The whole experience was underwhelming, and I ...
# 999  Then, as if I hadn't wasted enough of my life ...
#
# [1000 rows x 1 columns]

# %%
# pip install contractions

# %%
import contractions
from unidecode import unidecode
from string import punctuation
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
# import nltk
# nltk.download('stopwords')

# %%
def remove_lines(data):
    clean_text = data.replace("\n",' ').replace('\t',' ')
    return clean_text

# contraction mapping
def expand_text(data):
    expanded_doc=contractions.fix(data)
    return expanded_doc

# handled accented charactores
def accented_char(data):
    fixed_text=unidecode(data)
    return fixed_text

# %%
# import nltk
# print(nltk.data.path)

# %%
# import nltk
# nltk.download(info_or_id='stopwords')

# %%
# import nltk
# nltk.data.path.append(r'C:\ProgramData\Anaconda3\Lib\nltk_data\corpos\stopwords')

# %%
# import necessary library
from nltk.corpus import stopwords

# creating stopword list
stopword_list = stopwords.words('english')
stopword_list.remove('not')
stopword_list.remove('no')
stopword_list.remove('nor')

# %%
# clean data
def clean_data(data):
    tokens=word_tokenize(data)
    normalization=[word.lower() for word in tokens]
    remove_punc = [word for word in normalization if word not in punctuation]
    words_without_stop = [word for word in remove_punc if word not in stopword_list ]
    clean_text = [word for word in words_without_stop if len(word)>2]
    return clean_text
# lemmatization
def lemmatization(data):
    lemmatizer = WordNetLemmatizer()
    final_text = []
    for word in data :
        lemmatized_word = lemmatizer.lemmatize(word)
        final_text.append(lemmatized_word)
        return final_text

# %%
x_train, x_test, y_train, y_test = train_test_split(data.text)
